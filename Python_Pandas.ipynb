# %% [markdown]
# # Pandas básico

# %% [markdown]
# # Series
#
# Series são arrays unidimensionais rotulados e capazes de armazenar qualquer arquivo. Os rótulos das linhas são chamados de **index**. A forma básica de criação de uma Series é a seguinte.
#
# |
# #criando Series .
# s = pd.Series(dados, index = index)

# %% [markdown]
# # DataFrames
#
# DataFrame é uma estrutura de dados tabular bidimensional com rótulos nas linhas e colunas. Como a Series, os DataFrames são capazes de armazenar qualquer tipo de dados.
#
# |
#
# df = pd.DataFrame(dados, index = index, columns = columns)

# %% [markdown]
# # Estruturas de dados

# %%
import pandas as pd

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox']

# %%
pd.Series(carros)
# Out:
# 0    Jetta Variant
# 1           Passat
# 2         Crossfox
# dtype: object

# %% [markdown]
# # Criando um DataFrame a partir de uma lista de dicionários

# %%
dados = [
    {'Nome': 'Jetta Variant', 'Motor': 'Motor 4.0 Turbo', 'Ano': 2003, 'Quilometragem': 44410.0, 'Zero_km': False, 'Valor': 88078.64},
    {'Nome': 'Passat', 'Motor': 'Motor Diesel', 'Ano': 1991, 'Quilometragem': 5712.0, 'Zero_km': False, 'Valor': 106161.94},
    {'Nome': 'Crossfox', 'Motor': 'Motor Diesel V8', 'Ano': 1990, 'Quilometragem': 37123.0, 'Zero_km': False, 'Valor': 72932.16}
]

# %%
pd.DataFrame(dados)
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72932.16

# %% [markdown]
# # Criando DataFrame a partir de um dicionário

# %%
dados = {
    'Nome': ['Jetta Variant', 'Passat', 'Crossfox'],
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8'],
    'Ano': [2003, 1991, 1990],
    'Zero_km': [False, False, False],
    'Valor': [88078.64, 106161.94, 72932.16]
    }

# %%
pd.DataFrame(dados)
# Out:
#             Nome            Motor   Ano  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003    False   88078.64
# 1         Passat     Motor Diesel  1991    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990    False   72932.16

# %% [markdown]
# # **!!** Criando DataFrame a partir de um arquivo externo **!!**

# %%
dataset = pd.read_csv('db.csv', sep=';')

# %%
dataset
# Out:
#                       Nome  ...      Valor
# 0            Jetta Variant  ...   88078.64
# 1                   Passat  ...  106161.94
# 2                 Crossfox  ...   72832.16
# 3                      DS5  ...  124549.07
# 4         Aston Martin DB4  ...   92612.10
# ..                     ...  ...        ...
# 253           Phantom 2013  ...   51759.58
# 254  Cadillac Ciel concept  ...   51667.06
# 255             Classe GLK  ...   68934.03
# 256       Aston Martin DB5  ...  122110.90
# 257                  Macan  ...   90381.47
#
# [258 rows x 7 columns]
